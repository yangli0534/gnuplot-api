# %%
import pandas as pd
import numpy as np

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data_x = pd.read_csv('TX_CABLE_IL.csv',skiprows = [1,2], usecols=[0])
data_y = pd.read_csv('TX_CABLE_IL.csv',skiprows = [1,2], usecols=[1])
print(data_x)
print(data_y)
# Out:
#       # Channel 1
# 0    3.500000e+09
# 1    3.500000e+09
# 2    3.500000e+09
# 3    3.510000e+09
# 4    3.510000e+09
# ..            ...
# 196  3.890000e+09
# 197  3.890000e+09
# 198  3.900000e+09
# 199  3.900000e+09
# 200  3.900000e+09
#
# [201 rows x 1 columns]
#      Unnamed: 1
# 0         -44.6
# 1         -44.6
# 2         -44.7
# 3         -44.7
# 4         -44.7
# ..          ...
# 196       -44.4
# 197       -44.5
# 198       -44.6
# 199       -44.5
# 200       -44.5
#
# [201 rows x 1 columns]

# %%
freq = np.array(data_x)
freq = freq.tolist()
type(freq)
# Out:
# list

# %%
freq = pd.read_csv('TX_CABLE_IL.csv', skiprows=[1, 2], usecols=[0])
IL = pd.read_csv('TX_CABLE_IL.csv', skiprows=[1, 2], usecols=[1])

# %%
freq = np.array(freq)

# %%
type(freq)
freq=freq.reshape(freq.size)
print(freq.tolist())
# Out:
# [3500000000.0, 3500000000.0, 3500000000.0, 3510000000.0, 3510000000.0, 3510000000.0, 3510000000.0, 3510000000.0, 3520000000.0, 3520000000.0, 3520000000.0, 3520000000.0, 3520000000.0, 3530000000.0, 3530000000.0, 3530000000.0, 3530000000.0, 3530000000.0, 3540000000.0, 3540000000.0, 3540000000.0, 3540000000.0, 3540000000.0, 3550000000.0, 3550000000.0, 3550000000.0, 3550000000.0, 3550000000.0, 3560000000.0, 3560000000.0, 3560000000.0, 3560000000.0, 3560000000.0, 3570000000.0, 3570000000.0, 3570000000.0, 3570000000.0, 3570000000.0, 3580000000.0, 3580000000.0, 3580000000.0, 3580000000.0, 3580000000.0, 3590000000.0, 3590000000.0, 3590000000.0, 3590000000.0, 3590000000.0, 3600000000.0, 3600000000.0, 3600000000.0, 3600000000.0, 3600000000.0, 3610000000.0, 3610000000.0, 3610000000.0, 3610000000.0, 3610000000.0, 3620000000.0, 3620000000.0, 3620000000.0, 3620000000.0, 3620000000.0, 3630000000.0, 3630000000.0, 3630000000.0, 3630000000.0, 3630000000.0, 3640000000.0, 3640000000.0, 3640000000.0, 364
# ...
